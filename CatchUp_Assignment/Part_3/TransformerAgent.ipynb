# %% [markdown]
# <a href="https://colab.research.google.com/github/sidsanc/258_DeepLearning/blob/main/CatchUp_Assignment/Part_3/TransformerAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HF Transformers Agent

# %%
# !pip install transformers openai accelerate diffusers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.9/934.9 kB 40.3 MB/s eta 0:00:00

# %% [markdown]
# Make sure you have the right Transformers Version

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.29.0

# %% [markdown]
# Setting up OpenAI API Key

# %%
import openai
import os
os.environ['OPENAI_API_KEY'] = "sk-xxxx" #platform.openai.com

# %% [markdown]
# Create an Agent

# %%
from transformers import OpenAiAgent
agent = OpenAiAgent(model="text-davinci-003")

# %% [markdown]
# Agent RUN

# %%
agent.run("Draw me a picture of rivers and lakes.")
# Out:
# ==Explanation from the agent==
# I will use the following  tool: `image_generator` to generate an image according to the prompt.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="Draw me a picture of rivers and lakes.")
#
#
# ==Result==
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F0D57037D90>

# %%
agent.run("Draw me a picture of astronaut riding a horse")
# Out:
# ==Explanation from the agent==
# I will use the following  tool: `image_generator` to generate an image according to the prompt.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="Astronaut riding a horse")
#
#
# ==Result==
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F0D569EE890>

# %%
agent.run("Draw me a picture of astronaut riding a horse", return_code = True)
# Out:
# ==Explanation from the agent==
# I will use the following  tool: `image_generator` to generate an image according to the prompt.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="Astronaut riding a horse")
# 'from transformers import load_tool\n\nimage_generator = load_tool("huggingface-tools/text-to-image")\n\nimage = image_generator(prompt="Astronaut riding a horse")'

# %%
agent.chat("Draw me a picture of an astronaut riding a horse ")
# Out:
# ==Explanation from the agent==
# I will use the tool `image_generator` to create an image according to the prompt.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="An astronaut riding a horse")
#
#
# ==Result==
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F0D569ECB20>

# %%
agent.chat("Draw me a picture of a Horse instead of a Car?")
# Out:
# ==Explanation from the agent==
# I will use the tool `image_transformer` to modify the image according to the prompt.
#
#
# ==Code generated by the agent==
# modified_image = image_transformer(image, prompt="A horse instead of a car")
#
#
# ==Result==
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F0D51D6E740>
